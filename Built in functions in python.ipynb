# %%
import pandas as pd

# %%
tabla = pd.read_html('https://docs.python.org/3/library/functions.html')[0]

# %%
tabla.rename(columns = {'Unnamed: 0':'  ','Unnamed: 1':'  ','Built-in Functions':'  ',
                        'Unnamed: 3':'  ','Unnamed: 4':'  '})
# Out:
#
# 0           abs()       dict()        help()       min()       setattr()
# 1           all()        dir()         hex()      next()         slice()
# 2           any()     divmod()          id()    object()        sorted()
# 3         ascii()  enumerate()       input()       oct()  staticmethod()
# 4           bin()       eval()         int()      open()           str()
# 5          bool()       exec()  isinstance()       ord()           sum()
# 6     bytearray()     filter()  issubclass()       pow()         super()
# 7         bytes()      float()        iter()     print()         tuple()
# 8      callable()     format()         len()  property()          type()
# 9           chr()  frozenset()        list()     range()          vars()
# 10  classmethod()    getattr()      locals()      repr()           zip()
# 11      compile()    globals()         map()  reversed()    __import__()
# 12      complex()    hasattr()         max()     round()             NaN
# ...
